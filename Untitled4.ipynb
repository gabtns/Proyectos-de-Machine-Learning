# %% [markdown]
# <a href="https://colab.research.google.com/github/gabtns/Proyectos-de-Machine-Learning/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn import linear_model
import pandas as pd
import numpy as np

datos=pd.read_csv('/content/titanic.csv')

# %%
datos[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']]#Se extrae los datos de las columnas y se manifiesta en forma de dataframe.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Se obtienen las columnas donde se utilizaran para las variables regresoras y respuestas, se limpian los datos y se obtiene una fraccion de ellas
datos=datos.dropna(subset=['Fare','Pclass','Age','Survived'])
datos=datos.sample(frac=1).head(800)
x=datos[['Fare','Pclass','Age']]
y=datos['Survived']
#Se crea el modelo y se ajusta, al entranarse lo procedemos a verificar el nivel de acertacion en el cual se hace con R2_score.
modelo=linear_model.LinearRegression()
modelo.fit(x,y)
y_test=modelo.predict(x)
job=r2_score(y,y_test)
np.mean(y==y_test)
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
plt.scatter(datos['Survived'],datos['Age'],alpha=.1)
rect=Rectangle((0.0,40),0.0,20,
               alpha=.2,
               edgecolor='red',
               linewidth=2)
plt.title('Cantidad de personas que murieron y sobrevivieron')
plt.ylim(0,90)
# Out:
# (0.0, 90.0)

# %%
datos['Age'].mean()
# Out:
# 29.69911764705882
