# %% [markdown]
# <a href="https://colab.research.google.com/github/gabtns/Proyectos-de-Machine-Learning/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn import linear_model
import pandas as pd
import numpy as np

datos=pd.read_excel('/content/Ventas+Videojuegos.xlsx')

# %%
datos.columns
# Out:
# Index(['Nombre', 'Plataforma', 'Año', 'Genero', 'Editorial', 'Ventas NA',
#        'Ventas EU', 'Ventas JP', 'Ventas Otros', 'Ventas Global'],
#       dtype='object')

# %%
datos[['Nombre', 'Plataforma', 'Año', 'Genero', 'Editorial', 'Ventas NA',
       'Ventas EU', 'Ventas JP', 'Ventas Otros', 'Ventas Global']].head(20)
# Out:
#                                           Nombre Plataforma   Año  \
# 0                                     Wii Sports        Wii  2006
# 1                              Super Mario Bros.        NES  1985
# 2                                 Mario Kart Wii        Wii  2008
# 3                              Wii Sports Resort        Wii  2009
# 4                       Pokemon Red/Pokemon Blue         GB  1996
# 5                                         Tetris         GB  1989
# 6                          New Super Mario Bros.         DS  2006
# 7                                       Wii Play        Wii  2006
# 8                      New Super Mario Bros. Wii        Wii  2009
# 9                                      Duck Hunt        NES  1984
# 10                                    Nintendogs         DS  2005
# 11                                 Mario Kart DS         DS  2005
# 12                   Pokemon Gold/Pokemon Silver         GB  1999
# ...

# %%
datos=datos.dropna(subset=['Ventas NA','Ventas EU', 'Ventas JP', 'Ventas Otros'])
datos=datos.sample(frac=1).head(16000)
x=datos[['Ventas NA','Ventas EU', 'Ventas JP', 'Ventas Otros']]
y=datos['Ventas Global']

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=.5,random_state=2)
scal=StandardScaler()
scal.fit(x_train)
x_train=scal.transform(x_train)
x_test=scal.transform(x_test)
cml=MLPRegressor(hidden_layer_sizes=5, activation="relu", solver="lbfgs", alpha=0.0001,
                 batch_size="auto", learning_rate="constant", learning_rate_init=0.001, power_t=0.5,
                 max_iter=200, shuffle=True, random_state=2, tol=0.0001, verbose=False, 
                 warm_start=False, momentum=0.9, nesterovs_momentum=True,
                 early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, n_iter_no_change=10, max_fun=15000)

# %%
model=cml.fit(x_train,y_train)
predictive=model.predict(x_test)

# %%
r2_score(y_test,predictive)
# Out:
# 0.9999825056870303
